# %%
#  2, -2, sqrt(2): real numbers

# %% [markdown]
# # COMPLEX NUMBERS

# %% [markdown]
# - i^2 = -1
# - i^3 = -i, i^2*i = -1*i=> -i
# - i^4 = 1, i^2*i^2 = -1*-1 =>1

# %% [markdown]
# A complex number is a number that can be expressed in the form a + bi, where a and b are real numbers, and i represents the imaginary unit, satisfying the equation i² = −1. For example, 5+6i is a complex number, where 5 is a real number and 6i is an imaginary number. Therefore, the combination of both the real number and imaginary number is a complex number. There can be four types of algebraic operations on complex numbers which are mentioned below. The four operations on the complex numbers include:

# %% [markdown]
# - Addition
# - Subtraction
# - Multiplication
# - Division

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-15-13.png](attachment:Screenshot%20from%202022-12-10%2016-15-13.png)

# %%
5+6i, 5-6i

# %% [markdown]
# # Addition of Complex Numbers

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-16-46.png](attachment:Screenshot%20from%202022-12-10%2016-16-46.png)

# %% [markdown]
# Examples:

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-18-40.png](attachment:Screenshot%20from%202022-12-10%2016-18-40.png)

# %% [markdown]
# # Subtraction Of Complex Numbers

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-21-47.png](attachment:Screenshot%20from%202022-12-10%2016-21-47.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-22-33.png](attachment:Screenshot%20from%202022-12-10%2016-22-33.png)

# %% [markdown]
# # Multiplication of Complex Numbers

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-24-24.png](attachment:Screenshot%20from%202022-12-10%2016-24-24.png)

# %% [markdown]
# (2+3)*(4+5)
# (2+3)*4 + (2+3)*5
#
# (1+4i)*(3+5i)
# - =(1+4i)*3 + (1+4i)*5i
# - =3 + 12i + 5i + 20i^2
# - =3 + 12i +5i -20
# - =-17 + 17i

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-29-05.png](attachment:Screenshot%20from%202022-12-10%2016-29-05.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-29-40.png](attachment:Screenshot%20from%202022-12-10%2016-29-40.png)

# %% [markdown]
# - 3i *(2+6i)
# - 6i + 18i^2
# - 6i -18

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-30-20.png](attachment:Screenshot%20from%202022-12-10%2016-30-20.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-30-59.png](attachment:Screenshot%20from%202022-12-10%2016-30-59.png)

# %% [markdown]
# # Conjugate of a Complex Number

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-33-24.png](attachment:Screenshot%20from%202022-12-10%2016-33-24.png)

# %% [markdown]
# - 5+6i , 5-6i
# - 5+6i - (5-6i)
# - 0 + 12i

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-35-15.png](attachment:Screenshot%20from%202022-12-10%2016-35-15.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-35-15.png](attachment:Screenshot%20from%202022-12-10%2016-35-15.png)

# %% [markdown]
# # Division Of Complex Numbers

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-55-04.png](attachment:Screenshot%20from%202022-12-10%2016-55-04.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-56-29.png](attachment:Screenshot%20from%202022-12-10%2016-56-29.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-57-44.png](attachment:Screenshot%20from%202022-12-10%2016-57-44.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-58-58.png](attachment:Screenshot%20from%202022-12-10%2016-58-58.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2016-59-28.png](attachment:Screenshot%20from%202022-12-10%2016-59-28.png)

# %% [markdown]
# ![Screenshot%20from%202022-12-10%2017-00-02.png](attachment:Screenshot%20from%202022-12-10%2017-00-02.png)

# %% [markdown]
# # Modulus of complex number

# %% [markdown]
# a+ib
#
# - sqrt(a^2 + b^2)
#
# 4+5i
# - sqrt(4^2 + 5^2)
# - sqrt(16+25)
# - sqrt(41)
