# %% [markdown]
# # Tower of Hanoi

# %% [markdown]
# Tower of Hanoi, is a mathematical puzzle which consists of three towers (pegs) and more than one rings is as depicted −

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# These rings are of different sizes and stacked upon in an ascending order, i.e. the smaller one sits over the larger one. There are other variations of the puzzle where the number of disks increase, but the tower count remains the same.

# %% [markdown]
# Rules:
#
# The mission is to move all the disks to some another tower without violating the sequence of arrangement. A few rules to be followed for Tower of Hanoi are −
#
# - Only one disk can be moved among the towers at any given time.
#
# - Only the "top" disk can be removed.
#
# - No large disk can sit over a small disk.

# %% [markdown]
# Following is an animated representation of solving a Tower of Hanoi puzzle with three disks.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tower of Hanoi puzzle with n disks can be solved in minimum (2^n)−1 steps. This presentation shows that a puzzle with 3 disks has taken (2^3) - 1 = 7 steps.
#
# (2^64) -1 ~1B

# %% [markdown]
# # Algorithm

# %% [markdown]
# # algorithm
# 1. move (n-1) disks from source to auxillary tower.
# 2. move last plate,i.e., nth plate from source to destination
# 3. move (n-1) disks from auxillary tower to destination tower
#
# ##### (disk, from_which_tower_plates_r_picked, on_which_tower_plates_are_going_to_be_kept, helper_tower_which_may_or_mayn't_be_used
# tower(disk, source, destination, aux)
#     if disk==1:
#         move disk from source to destination
#     else:
#         tower(disk-1, source, auxillary, destination)
#         move largest disk from source to destination
#         tower(disk-1, aux, destination, source)

# %%
def tower_of_hanoi(n, source, destination, aux):  #(3,A,C,B) #(2,A,B,C) #(1,A,C,B)
    if n == 0:
        return
    else:
        tower_of_hanoi(n-1, source, aux, destination) #(2,A,B,C) #(1,A,C,B)
        print("move the disk", n, "from the tower:", source, "to tower:", destination)
        tower_of_hanoi(n-1, aux, destination, source)
        
n = 3
tower_of_hanoi(3, 'A', 'C', 'B')
# Out:
# move the disk 1 from the tower: A to tower: C
# move the disk 2 from the tower: A to tower: B
# move the disk 1 from the tower: C to tower: B
# move the disk 3 from the tower: A to tower: C
# move the disk 1 from the tower: B to tower: A
# move the disk 2 from the tower: B to tower: C
# move the disk 1 from the tower: A to tower: C
