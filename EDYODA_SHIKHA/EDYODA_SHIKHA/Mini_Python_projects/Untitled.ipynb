# %% [markdown]
# # Python program to create a simple calculator

# %%
def add(x,y):
    return x+y

def subtract(x,y):
    return x-y

def multiply(x,y):
    return x*y

def divide(x,y):
    return x/y

print("selct operation:")
print("1. Add")
print("2. Subtract")
print("3. Multiply")
print("4. Divide")

while True:
    choice = input("enter choice: 1/2/3/4")
    
    if choice in('1', '2', '3', '4'):
        num1 = float(input("enter first number"))
        num2 = float(input("enter first number"))
        
        if choice == '1':
            print(num1, "+", num2, "=", add(num1, num2))

        elif choice == '2':
            print(num1, "-", num2, "=", subtract(num1, num2))

        elif choice == '3':
            print(num1, "x", num2, "=", nultiply(num1, num2))

        elif choice == '4':
            print(num1, "/", num2, "=", divide(num1, num2))
            
        next_calc = input("Let's do next calculation? (y/n)")
        if next_calc == "no":
            break
            
    else:
        print("Invalid input")
# Out:
# selct operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# enter choice: 1/2/3/42
# enter first number10
# enter first number20
# 10.0 - 20.0 = -10.0

# %% [markdown]
# # Dice Roll Simulator

# %% [markdown]
# The goal is to create a program that will simulate the roll of dice.

# %% [markdown]
# Hint: Using a random module generate a random number between the range from 1 to 6 when the user wants.

# %%
import random

while True:
    print("1. Roll the dice   2. exit")
    user = int(input("enter 1 or 2"))
    if user==1:
        number = random.randint(1,6)
        print("random number generated: ", number)
        
    else:
        break
# Out:
# 1. Roll the dice   2. exit
# enter 1 or 21
# random number generated:  2
# 1. Roll the dice   2. exit
# enter 1 or 22

# %% [markdown]
# # Random password generator

# %% [markdown]
# To create a program that takes a number and generate a random password length of that number.

# %% [markdown]
# Hint: Create a string with all characters, then take random characters from it and concatenate each char to make a big string.

# %%
import random

passlen = int(input("enter the length of password"))
s = "abcdefghijklmnopqrstuvwxyz0123456789ABCDEFGHIKJKLMNOPQRSTUVWXYZ!@#$%^&*()?"
generated_pwd = "".join(random.sample(s, passlen))
print(generated_pwd)
# Out:
# enter the length of password6
# 6BF&er

# %% [markdown]
# # Binary Search in Python

# %%
[10, 20, 30,40] 
# condition of binary search: the list should be sorted

# %% [markdown]
# Problem:
#
# Given a sorted array arr[] of n elements, write a function to search a given element x in arr[] and return the index of x in the array.

# %% [markdown]
# Examples:
#
# Input: arr[] = {10, 20, 30, 50, 60, 80, 110, 130, 140, 170}, x = 110
#
# Output: 6
#
# Explanation: Element x is present at index 6.

# %% [markdown]
# Input: arr[] = {10, 20, 30, 40, 60, 110, 120, 130, 170}, x = 175
#
# Output: -1
#
# Explanation: Element x is not present in arr[].

# %% [markdown]
# Linear Search Approach:
#
# A simple approach is to do a linear search. The time complexity of the Linear search is O(n). Another approach to perform the same task is using Binary Search.

# %% [markdown]
# Binary Search Approach:
#
# Binary Search is a searching algorithm used in a sorted array by repeatedly dividing the search interval in half. The idea of binary search is to use the information that the array is sorted and reduce the time complexity to O(Log n).

# %% [markdown]
# Binary Search Algorithm: The basic steps to perform Binary Search are:
#
#
# 1. Begin with the mid element of the whole array as a search key.
# 2. If the value of the search key is equal to the item then return an index of the search key.
# 3. Or if the value of the search key is less than the item in the middle of the interval, narrow the interval to the lower half.
# 4. Otherwise, narrow it to the upper half.
# 5. Repeatedly check from the second point until the value is found or the interval is empty.
#
# Binary Search Algorithm can be implemented in the following two ways:
#
# - Iterative Method
# - Recursive Method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# mid = (low+high)/2

# %% [markdown]
# - if the no. we're searching == mid: return mid otherwise move to further comparison
#
# - if the no. we're searching > mid: low = mid+1 & search the no. on right half
#
# -  if the no. we're searching < mid: high = mid-1 & search the no. on left half

# %%
def binary_search(list1, n):            #[], 100
    low = 0                             #l=0
    high = len(list1) - 1               #h=6
    mid  = 0                            #m=0
    
    while low <= high:                                       #l=4 ; 4<=6                  #l=6; 6<=6        #l=7;7<=6
        mid = (high+low) // 2          #m=3                   #m=(4+6)//2 = 5             mid=(6+6)//2=>6
        
        # if n is greater, compared to the left of mid
        if list1[mid] < n:            #list1[3] < 100        #list1[5] < 100              #list1[6] < 100
            low = mid + 1             #l = 3+1=>4             low=5+1=>6                 l=6+1=>7
            
        #if n is smaller than mid, compare to the right of mid
        elif list1[mid] > n:
            high = mid - 1
            
        # if n is present at mid of the position
        else:
            return mid
        
    return -1
    # return "element is not present in the list"

list1 = [12, 24, 32, 39, 45, 50, 54]
n = 100

result = binary_search(list1, n)
if result != -1:
    print("Element is present at index", str(result))
else:
    print("Element is not present in provided list")
# Out:
# Element is present at index 4

# %% [markdown]
# # time complexity of binary search: O(logn)

# %%
for j in range(n):             i+2
    print(j)      #O(n)
    
    
def power(n):
    for j in range(2, n, 2):     #i+2         
        print(j)
        
n=10
2, 4, 8, 16

# 2^3 = 8
# log8 with base 2 = 3

# %% [markdown]
# # Quiz Maker

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
question_prompt = [
    "What is the color of apple? \n (a) red (b) yellow",
    "What is the color of banana? \n (a) pyrple (b) yellow",
]

# %%
class Question:
    
    def __init__(self, prompt, answer):
        self.prompt = prompt
        self.answer = answer

# %%
questions = [Question(question_prompt[0], "a"),
            Question(question_prompt[1], "b")]

# %%
def run_test(questions):
    
    score = 0
    for question in questions:
        user_ans = input(question.prompt)
        if user_ans == question.answer:
            score += 1

# %%
def add(a,b):
    return a+b

try:
    x = add(2)
    print(x)
except Exception as e:
    print(e)
    pass

print("passed after exception")
# Out:
# add() missing 1 required positional argument: 'b'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [14], line 9
#       7 except Exception as e:
#       8     print(e)
# ----> 9     raise e
#      11 print("passed after exception")
#
# Cell In [14], line 5
#       2     return a+b
#       4 try:
# ----> 5     x = add(2)
#       6     print(x)
#       7 except Exception as e:
#
# TypeError: add() missing 1 required positional argument: 'b'
